# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('numeros_20.txt')
x_training = data[0:10,0]
y_training = data[0:10,1]
x_test = data[10:,0]
y_test = data[10:,1]
Erms_Training = []
Erms_Test = []
#Vector Beta
fig=plt.figure(figsize=(20,30))
for s in range(10):
    m=s+1
    n=10
    X = np.zeros((n, m))
    for i in range(n):
        for ii in range(m):
            X[i, ii] = x_training[i]**ii
    beta = np.matmul(np.linalg.pinv(X), y_training[0:n])
    x = np.linspace(0,1,100)
    y = np.zeros(100)
    for i in range(x.shape[0]):
        for j in range(beta.shape[0]):
            y[i] += beta[j]*x[i]**j
    plt.subplot(5,2,m)
    plt.scatter(x_training, y_training)
    plt.plot(x, y, c='red')
    plt.ylim(0,2)
    plt.title(r'$M=$'+str(s))
    plt.xlabel(r'$X$')
    plt.ylabel(r'$Y$')
#plt.show()
    
    y_Training = np.zeros(10)
    for i in range(10):
        for j in range(m):
            y_Training[i] += beta[j]*x_training[i]**j
    E_Training = []
    for i in range(10):
        E_Training.append(1/2 * (y_Training[i] - y_training[i])**2)  
    E = sum(E_Training) 
    Erms_Training.append(np.sqrt(2 * E / 10))
    
    y_Test = np.zeros(10)
    for i in range(10):
        for j in range(m):
            y_Test[i] += beta[j]*x_test[i]**j
    E_Test = []
    for i in range(10):
        E_Test.append(1/2 * (y_Test[i] - y_test[i])**2)  
    E_ = sum(E_Test) 
    Erms_Test.append(np.sqrt(2 * E_ / 10))

M = []
for i in range(10):
    M.append(i)
plt.figure()
plt.plot(M, Erms_Training, 'b-o',label='$E_{Training}$')
plt.plot(M, Erms_Test,'r-o',label='$E_{Test}$')
plt.xlabel('$M$')
plt.ylabel('$E_{RMS}$')
plt.legend()
plt.show()

# %%
Erms_Test = []
#Vector Beta
for s in range(10):
    m=s+1
    n=10
    X = np.zeros((n, m))
    for i in range(n):
        for ii in range(m):
            X[i, ii] = x_test[i]**ii
    beta = np.matmul(np.linalg.pinv(X), y_test[0:n])
    x = np.linspace(0,1,100)
    y = np.zeros(100)
    for i in range(x.shape[0]):
        for j in range(beta.shape[0]):
            y[i] += beta[j]*x[i]**j
    plt.scatter(x_test, y_test)
    plt.plot(x, y, c='red')
    plt.ylim(0,2)
    plt.title(s)
    plt.xlabel('$X$')
    plt.ylabel('$Y$')
    plt.show()
    
    y_Test = np.zeros(10)
    for i in range(10):
        for j in range(m):
            y_Test[i] += beta[j]*x_training[i]**j
    E_Training = []
    for i in range(10):
        E_Training.append(1/2 * (y_Training[i] - y_training[i])**2)  
    E = sum(E_Training) 
    Erms_Training.append(np.sqrt(2 * E / 10))

# %%
#Training

for m in range(11):
    y_Training = np.zeros(10)
    for i in range(10):
        for j in range(m):
            y_Training[i] += beta[j]*x_training[i]**j
    E_Training = []
    for i in range(10):
        E_Training.append(1/2 * (y_Training[i] - y_training[i])**2)  
    E = sum(E_Training)
    E_Training = np.array(E_Training)        
    Erms_Training = np.sqrt(2 * E / 10)

Erms_Training
#plt.plot(M, Erms_Training, 'b-o',label='$E_{Training}$')
#plt.xlabel('$M$')
#plt.ylabel('$E_{RMS}$')
#plt.legend()
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-d82ad6b1f1b3> in <module>()
#      11     E = sum(E_Training)
#      12     E_Training = np.array(E_Training)
# ---> 13     Erms_Training = np.sqrt(2 * E[a] / 10)
#      14
#      15 Erms_Training
#
# IndexError: invalid index to scalar variable.

# %%
#Test
y_Test = np.zeros(10)
for i in range(10):
    for j in range(m):
        y_Test[i] += beta[j]*x_test[i]**j
print(y_Test)
E_Test = []
for i in range(10):
    E_Test.append(1/2 * (y_Test[i] - y_test[i])**2)  
E_Test = np.array(E_Test)      
Erms_Test = np.sqrt(2 * E_Test / 10)

#print(Erms_Test)

#plt.plot(M, Erms_Training, c='blue',label='$E_{Training}$')
plt.plot(M, Erms_Test, 'r-o',label='$E_{Test}$')
plt.xlabel('$M$')
plt.ylabel('$E_{RMS}$')
plt.legend()
plt.show()
# Out:
# [ 1.19107766e+00 -1.21655825e+04  2.04829175e+00  2.66593220e+00
#   2.83121920e+00  1.62257292e+00  1.15673942e+00  6.80939642e-01
#  -4.74196007e+02  1.15522335e+00]
